# %%
for i in[1,2,3,4,5,4,3,2,1]:
  print(i)
print('Blastoff')
# Out:
# 1
# 2
# 3
# 4
# 5
# 4
# 3
# 2
# 1
# Blastoff

# %%
for i in range (0, 10):
  print(i)
  print("printing i")
print("blastoff")
# Out:
# 0
# printing i
# 1
# printing i
# 2
# printing i
# 3
# printing i
# 4
# printing i
# 5
# printing i
# 6
# printing i
# 7
# printing i
# 8
# printing i
# 9
# printing i
# blastoff
