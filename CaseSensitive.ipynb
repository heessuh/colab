# %%
number = 5
print (number)
# Out:
# 5

# %%
number = 5
print (Number)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-c2ae9045bff5> in <module>()
#       1 number = 5
# ----> 2 print (Number)
#
# NameError: name 'Number' is not defined

# %%
my-number = 5
# Out:
#   File "<ipython-input-3-599dec50de5a>", line 1
#     my-number = 5
#                  ^
# SyntaxError: can't assign to operator
