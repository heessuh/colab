# %%
friends=['chibata', 'hammer', 'superman', 'batman']
for friend in friends:
  print('happy new year, ', friend)
print('done')
# Out:
# happy new year,  chibata
# happy new year,  hammer
# happy new year,  superman
# happy new year,  batman
# done
