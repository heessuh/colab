# %%
import pandas as pd
import matplotlib.pyplot as plt #from matplotlib import pyplot as plt

x = [1,2,3,5,8]
y = [2,8,10,24,36]
plt.title("test")
plt.xlabel("icecreams")
plt.ylabel("popcorn")
graph = plt.plot(x,y)
plt.show(graph)
