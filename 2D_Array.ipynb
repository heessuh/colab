# %%
from array import *

T = [[11, 12, 5, 2], [15, 6,10], [10, 8, 12, 5], [12,15,8,6]]

for r in T:
  print(r)
# Out:
# [11, 12, 5, 2]
# [15, 6, 10]
# [10, 8, 12, 5]
# [12, 15, 8, 6]

# %%
list_a = [1,2,3,4,5]
list_b = ['A','E','I','I','U']

list_joined = list(zip(list_a, list_b)) 


print(list_joined)
# Out:
# [(1, 'A'), (2, 'E'), (3, 'I'), (4, 'I'), (5, 'U')]
