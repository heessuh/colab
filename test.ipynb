# %%
number = 7
print (number)
# Out:
# 7

# %%
number = 9
print(number)
# Out:
# 9

# %%
number = "To     "
number = number + 'm'
print (number)()
# Out:
# To     m

# %%
number = 10
if number > 4:
  print("voila")
  print("true")
# Out:
# voila
# true

# %%
var = "8" + "     9"
print (var)
len(var) #len length
list = []
len(list)
list =[ "artur", "paola", "henzo"]
# Out:
# 8     9
# 7
