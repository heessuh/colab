# %%
# == < <= > >= != # pound hashmark
superman = 5
if superman == 5:
  print("equals")
#if superman < 6:
  #print ("less than")
if superman <= 5:
  print("less than or euqals")
if superman > 3:
  print ("greater than")
if superman >= 5:
  print("greater than or euqals")
# not equal to ! bang=
#if superman != 8:
  #print("not equals")
# Out:
# equals
# less than or euqals
# greater than
# greater than or euqals
