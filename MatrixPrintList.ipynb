# %%
import numpy as np
students = [["James", "Smith",89,78],["Mary", "Johnson",89,80],["John", "Williams",78,78],["Patrica", "Jones",89,67], ["Linda","Brown",88,70]]
#grades = [[89,78], [89,80],[78,78],[89,67],[88,70]]
print(np.matrix(students))
# Out:
# [['James' 'Smith' '89' '78']
#  ['Mary' 'Johnson' '89' '80']
#  ['John' 'Williams' '78' '78']
#  ['Patrica' 'Jones' '89' '67']
#  ['Linda' 'Brown' '88' '70']]
